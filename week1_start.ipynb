# %%
import pandas as pd

# %%
# !which python

# %%
df = pd.read_csv('Data-Collisions.csv', low_memory=False)

# %%
df[df['ROADCOND'].isnull()]

# %%
# Out:
# /home/taz/.local/share/virtualenvs/Coursera_Capstone-5j-Ycuah/bin/python

# %%
df = pd.read_csv('Data-Collisions.csv', low_memory=False)

# %%
df[df['ROADCOND'].isnull()]
# Out:
#         SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 15                 1 -122.337663  47.617510        20  330878     332378
# 36                 1 -122.335727  47.613363        45  330925     332425
# 53                 2 -122.307866  47.570915        63  330824     332324
# 60                 1 -122.335571  47.521783        72  330841     332341
# 75                 1 -122.360524  47.519195        87  320926     322426
# ...              ...         ...        ...       ...     ...        ...
# 194620             1 -122.377549  47.668671    219484  308942     310222
# 194625             1 -122.337552  47.589374    219491  308378     309658
# 194646             1 -122.320756  47.608656    219513  312289     313709
# 194654             1 -122.312679  47.719414    219522  311117     312437
# 194655             2 -122.380016  47.664879    219523  310911     312231
#
#        REPORTNO     STATUS      ADDRTYPE    INTKEY  ... ROADCOND LIGHTCOND  \
# ...
